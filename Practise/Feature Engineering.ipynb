# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.pandas.set_option('display.max_columns',None)

# %%
dframe_Feature_Engg = pd.read_csv('D:\Practise\House Price.csv')
dframe_Feature_Engg.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(dframe_Feature_Engg, dframe_Feature_Engg['SalePrice'], test_size = 0.1, random_state = 42)

X_train.shape, X_test.shape
# Out:
# ((1314, 81), (146, 81))

# %% [markdown]
# ## Missing values

# %%
features_na = [feature for feature in dframe_Feature_Engg.columns if dframe_Feature_Engg[feature].isnull().sum() > 1 and dframe_Feature_Engg[feature].dtypes =='O']

print(features_na)
# Out:
# ['Alley', 'MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature']

# %%
#Replace the missing values with new label

def replace_cat_feature(dataset, feature_nan):
    data = dframe_Feature_Engg.copy()
    data[feature_nan] = data[feature_nan].fillna('Missing')
    return data

# %%
dframe_Feature_Engg = replace_cat_feature(dframe_Feature_Engg, features_na)

# %%
dframe_Feature_Engg[features_na].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
dframe_Feature_Engg.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  Missing      Reg
# 1   2          20       RL         80.0     9600   Pave  Missing      Reg
# 2   3          60       RL         68.0    11250   Pave  Missing      IR1
# 3   4          70       RL         60.0     9550   Pave  Missing      IR1
# 4   5          60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
#Check the missing values for numeric values

numeric_features = [feature for feature in dframe_Feature_Engg.columns if dframe_Feature_Engg[feature].isnull().sum() > 1 and dframe_Feature_Engg[feature].dtypes != 'O' ]

print(numeric_features)
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
for feature in numeric_features:
    median_val = dframe_Feature_Engg[feature].median()
    dframe_Feature_Engg[feature] = np.where(dframe_Feature_Engg[feature].isnull(),median_val, dframe_Feature_Engg[feature])

# %%
dframe_Feature_Engg[numeric_features].head(50)
# Out:
#     LotFrontage  MasVnrArea  GarageYrBlt
# 0          65.0       196.0       2003.0
# 1          80.0         0.0       1976.0
# 2          68.0       162.0       2001.0
# 3          60.0         0.0       1998.0
# 4          84.0       350.0       2000.0
# 5          85.0         0.0       1993.0
# 6          75.0       186.0       2004.0
# 7          69.0       240.0       1973.0
# 8          51.0         0.0       1931.0
# 9          50.0         0.0       1939.0
# 10         70.0         0.0       1965.0
# 11         85.0       286.0       2005.0
# 12         69.0         0.0       1962.0
# 13         91.0       306.0       2006.0
# 14         69.0       212.0       1960.0
# 15         51.0         0.0       1991.0
# 16         69.0       180.0       1970.0
# 17         72.0         0.0       1967.0
# 18         66.0         0.0       2004.0
# 19         70.0         0.0       1958.0
# 20        101.0       380.0       2005.0
# 21         57.0         0.0       1930.0
# ...

# %%
dframe_Feature_Engg[numeric_features].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
dframe_Feature_Engg.head(50)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave  Missing      Reg
# 1    2          20       RL         80.0     9600   Pave  Missing      Reg
# 2    3          60       RL         68.0    11250   Pave  Missing      IR1
# 3    4          70       RL         60.0     9550   Pave  Missing      IR1
# 4    5          60       RL         84.0    14260   Pave  Missing      IR1
# 5    6          50       RL         85.0    14115   Pave  Missing      IR1
# 6    7          20       RL         75.0    10084   Pave  Missing      Reg
# 7    8          60       RL         69.0    10382   Pave  Missing      IR1
# 8    9          50       RM         51.0     6120   Pave  Missing      Reg
# 9   10         190       RL         50.0     7420   Pave  Missing      Reg
# 10  11          20       RL         70.0    11200   Pave  Missing      Reg
# ...

# %% [markdown]
# ## Temporal Variables

# %%
temporal_features = [feature for feature in dframe_Feature_Engg.columns if 'Yr' in feature or 'Year' in feature]
print(temporal_features)
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for feature in ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt']:
    dframe_Feature_Engg[feature] = dframe_Feature_Engg['YrSold'] - dframe_Feature_Engg[feature]

# %%
dframe_Feature_Engg[temporal_features].head(10)
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# 0          5             5          5.0    2008
# 1         31            31         31.0    2007
# 2          7             6          7.0    2008
# 3         91            36          8.0    2006
# 4          8             8          8.0    2008
# 5         16            14         16.0    2009
# 6          3             2          3.0    2007
# 7         36            36         36.0    2009
# 8         77            58         77.0    2008
# 9         69            58         69.0    2008

# %% [markdown]
# ## Numerical Variables

# %%
numeric_features
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
print(dframe_Feature_Engg.columns)
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
num_features=['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice']

for feature in num_features:
    dframe_Feature_Engg[feature] = np.log(dframe_Feature_Engg[feature])

# %%
dframe_Feature_Engg.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0   1          60       RL     4.174387  9.041922   Pave  Missing      Reg
# 1   2          20       RL     4.382027  9.169518   Pave  Missing      Reg
# 2   3          60       RL     4.219508  9.328123   Pave  Missing      IR1
# 3   4          70       RL     4.094345  9.164296   Pave  Missing      IR1
# 4   5          60       RL     4.430817  9.565214   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
for feature in num_features:
##    dframe_Feature_Engg[feature].hist(bins = 20)
    sns.distplot(dframe_Feature_Engg[feature])
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# ## Handling Categorical Features

# %%
categorical_feature = [feature for feature in dframe_Feature_Engg.columns if dframe_Feature_Engg[feature].dtype == 'O']

##print(categorical_feature.dtype)

# %%
len(categorical_feature)
# Out:
# 43

# %%
categorical_feature
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
for feature in categorical_feature:
    temp = dframe_Feature_Engg.groupby(feature)['SalePrice'].count()/len(dframe_Feature_Engg)
    temp_df = temp[temp > 0.01].index
    dframe_Feature_Engg[feature] = np.where(dframe_Feature_Engg[feature].isin(temp_df),dframe_Feature_Engg[feature], 'rare_var')

# %%
dframe_Feature_Engg.iloc[93,]
# Out:
# Id                     94
# MSSubClass            190
# MSZoning         rare_var
# LotFrontage       4.09434
# LotArea           8.88184
#                    ...
# MoSold                 11
# YrSold               2007
# SaleType               WD
# SaleCondition      Normal
# SalePrice         11.8048
# Name: 93, Length: 81, dtype: object

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
feature_scale = [feature for feature in dframe_Feature_Engg.columns if (dframe_Feature_Engg[feature].dtypes != 'O' and feature != 'Id')]

feature_scale
# Out:
# ['MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
scaler = MinMaxScaler()
scaler.fit(dframe_Feature_Engg[feature_scale])
scaler.transform(dframe_Feature_Engg[feature_scale])
# Out:
# array([[0.23529412, 0.41820812, 0.3663439 , ..., 0.09090909, 0.5       ,
#         0.58143069],
#        [0.        , 0.49506375, 0.39131677, ..., 0.36363636, 0.25      ,
#         0.53631912],
#        [0.23529412, 0.434909  , 0.4223585 , ..., 0.72727273, 0.5       ,
#         0.60402899],
#        ...,
#        [0.29411765, 0.42385922, 0.37959669, ..., 0.36363636, 1.        ,
#         0.66126699],
#        [0.        , 0.434909  , 0.39368765, ..., 0.27272727, 1.        ,
#         0.45677119],
#        [0.        , 0.47117546, 0.39806941, ..., 0.45454545, 0.5       ,
#         0.46884616]])

# %%
X_train = pd.concat([dframe_Feature_Engg['Id'], 
                     pd.DataFrame(scaler.transform(dframe_Feature_Engg[feature_scale]), columns = feature_scale)],
                     axis = 1)

# %%
X_train.head()
# Out:
#    Id  MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1    0.235294     0.418208  0.366344     0.666667        0.500   0.036765
# 1   2    0.000000     0.495064  0.391317     0.555556        0.875   0.227941
# 2   3    0.235294     0.434909  0.422359     0.666667        0.500   0.051471
# 3   4    0.294118     0.388581  0.390295     0.666667        0.500   0.669118
# 4   5    0.235294     0.513123  0.468761     0.777778        0.500   0.058824
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0      0.098361     0.12250    0.125089         0.0   0.064212     0.140098
# 1      0.524590     0.00000    0.173281         0.0   0.121575     0.206547
# 2      0.114754     0.10125    0.086109         0.0   0.185788     0.150573
# 3      0.606557     0.00000    0.038271         0.0   0.231164     0.123732
# 4      0.147541     0.21875    0.116052         0.0   0.209760     0.187398
#
# ...

# %%
y_train = X_train.pop("SalePrice")

# %%
y_train.head()
# Out:
# 0    0.581431
# 1    0.536319
# 2    0.604029
# 3    0.451871
# 4    0.640477
# Name: SalePrice, dtype: float64

# %%
X_train.head()
# Out:
#    Id  MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1    0.235294     0.418208  0.366344     0.666667        0.500   0.036765
# 1   2    0.000000     0.495064  0.391317     0.555556        0.875   0.227941
# 2   3    0.235294     0.434909  0.422359     0.666667        0.500   0.051471
# 3   4    0.294118     0.388581  0.390295     0.666667        0.500   0.669118
# 4   5    0.235294     0.513123  0.468761     0.777778        0.500   0.058824
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0      0.098361     0.12250    0.125089         0.0   0.064212     0.140098
# 1      0.524590     0.00000    0.173281         0.0   0.121575     0.206547
# 2      0.114754     0.10125    0.086109         0.0   0.185788     0.150573
# 3      0.606557     0.00000    0.038271         0.0   0.231164     0.123732
# 4      0.147541     0.21875    0.116052         0.0   0.209760     0.187398
#
# ...

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
X_train.drop('Id', axis =1, inplace = True)

# %%
X_train.head()
# Out:
#    MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0    0.235294     0.418208  0.366344     0.666667        0.500   0.036765
# 1    0.000000     0.495064  0.391317     0.555556        0.875   0.227941
# 2    0.235294     0.434909  0.422359     0.666667        0.500   0.051471
# 3    0.294118     0.388581  0.390295     0.666667        0.500   0.669118
# 4    0.235294     0.513123  0.468761     0.777778        0.500   0.058824
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0      0.098361     0.12250    0.125089         0.0   0.064212     0.140098
# 1      0.524590     0.00000    0.173281         0.0   0.121575     0.206547
# 2      0.114754     0.10125    0.086109         0.0   0.185788     0.150573
# 3      0.606557     0.00000    0.038271         0.0   0.231164     0.123732
# 4      0.147541     0.21875    0.116052         0.0   0.209760     0.187398
#
# ...

# %%
feature_select_mod = SelectFromModel(Lasso(alpha = 0.05, random_state = 0))
feature_select_mod.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.05, random_state=0))

# %%
feature_select_mod.get_support()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False])

# %%
select_feat = X_train.columns[(feature_select_mod.get_support())]
select_feat
# Out:
# Index([], dtype='object')

# %%
#Recursive Feature Elimination (RFE)

rfe_selector = RFE(estimator=LogisticRegression(),n_features_to_select = 2, step = 1)
rfe_selector.fit(X, y)
X.columns[rfe_selector.get_support()]
